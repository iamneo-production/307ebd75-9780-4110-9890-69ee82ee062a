# %%
import pandas as pd

# %%
df = pd.read_csv(r"..\full.csv")
df.head()
# Out:
# C:\Users\Sravya.nekkanti\AppData\Local\Temp\ipykernel_5696\2144813585.py:1: DtypeWarning: Columns (4,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"C:\Users\Sravya.nekkanti\OneDrive\Desktop\NASSCOM\Heatwave\Datasets\Year Wise\2018 to 2022 Curated\full.csv")
#    Unnamed: 0.2  row_id            District Mandal  location        Date  \
# 0             0     0.0  Medchal-Malkajgiri  Uppal  Moulali   01-01-2018
# 1             1     1.0  Medchal-Malkajgiri  Uppal  Moulali   02-01-2018
# 2             2     2.0  Medchal-Malkajgiri  Uppal  Moulali   03-01-2018
# 3             3     3.0  Medchal-Malkajgiri  Uppal  Moulali   04-01-2018
# 4             4     4.0  Medchal-Malkajgiri  Uppal  Moulali   05-01-2018
#
#    Rainfall (mm)  temp_min  temp_max  humidity_min  ...  humidity_min (%)  \
# 0            0.0      12.1      32.6          23.8  ...               NaN
# 1            0.0      11.6      32.6          23.2  ...               NaN
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0.2               int64
# row_id                   float64
# District                  object
# Mandal                    object
# location                  object
# Date                      object
# Rainfall (mm)            float64
# temp_min                 float64
# temp_max                 float64
# humidity_min             float64
# humidity_max             float64
# wind_speed_min           float64
# wind_speed_max           float64
# Unnamed: 0.1             float64
# humidity_min (%)          object
# Humidity_max (%)         float64
# wind_speed_min (Kmph)    float64
# wind_speed_max (Kmph)    float64
# Unnamed: 0               float64
# humidity_max (%)         float64
# Min Humidity (%)         float64
# Max Humidity (%)         float64
# Min Wind Speed (Kmph)    float64
# Max Wind Speed (Kmph)    float64
# dtype: object

# %%
from matplotlib import pyplot as plt
df.columns
# Out:
# Index(['Unnamed: 0.2', 'row_id', 'District', 'Mandal', 'location', 'Date',
#        'Rainfall (mm)', 'temp_min', 'temp_max', 'humidity_min', 'humidity_max',
#        'wind_speed_min', 'wind_speed_max', 'Unnamed: 0.1', 'humidity_min (%)',
#        'Humidity_max (%)', 'wind_speed_min (Kmph)', 'wind_speed_max (Kmph)',
#        'Unnamed: 0', 'humidity_max (%)', 'Min Humidity (%)',
#        'Max Humidity (%)', 'Min Wind Speed (Kmph)', 'Max Wind Speed (Kmph)'],
#       dtype='object')

# %%
df1 = df.query('Mandal == "Warangal" and location == "Kasibugga"')
df1
# Out:
#         Unnamed: 0.2    row_id      District    Mandal   location        Date  \
# 202950        202950  202950.0  Warangal (U)  Warangal  Kasibugga  01-01-2018
# 202951        202951  202951.0  Warangal (U)  Warangal  Kasibugga  02-01-2018
# 202952        202952  202952.0  Warangal (U)  Warangal  Kasibugga  03-01-2018
# 202953        202953  202953.0  Warangal (U)  Warangal  Kasibugga  04-01-2018
# 202954        202954  202954.0  Warangal (U)  Warangal  Kasibugga  05-01-2018
# ...              ...       ...           ...       ...        ...         ...
# 315553        315553  221732.0  Warangal (U)  Warangal  Kasibugga  27-12-2018
# 315554        315554  221733.0  Warangal (U)  Warangal  Kasibugga  28-12-2018
# 315555        315555  221734.0  Warangal (U)  Warangal  Kasibugga  29-12-2018
# 315556        315556  221735.0  Warangal (U)  Warangal  Kasibugga  30-12-2018
# 315557        315557  221736.0  Warangal (U)  Warangal  Kasibugga  31-12-2018
#
# ...

# %%
df2 = df.query('Mandal == "Warangal" and location.isnull()')
df2
# Out:
#          Unnamed: 0.2  row_id      District    Mandal location        Date  \
# 401652          83520     NaN  Warangal (U)  Warangal      NaN  01-01-2019
# 401653          83521     NaN  Warangal (U)  Warangal      NaN  02-01-2019
# 401654          83522     NaN  Warangal (U)  Warangal      NaN  03-01-2019
# 401655          83523     NaN  Warangal (U)  Warangal      NaN  04-01-2019
# 401656          83524     NaN  Warangal (U)  Warangal      NaN  05-01-2019
# ...               ...     ...           ...       ...      ...         ...
# 1173100        161617     NaN      Warangal  Warangal      NaN   26-Sep-22
# 1173101        161618     NaN      Warangal  Warangal      NaN   27-Sep-22
# 1173102        161619     NaN      Warangal  Warangal      NaN   28-Sep-22
# 1173103        161620     NaN      Warangal  Warangal      NaN   29-Sep-22
# 1173104        161621     NaN      Warangal  Warangal      NaN   30-Sep-22
#
#          Rainfall (mm)  temp_min  temp_max  humidity_min  ...  \
# ...

# %%
frames = [df1, df2]
df = pd.concat(frames)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.head()
# Out:
# C:\Users\Sravya.nekkanti\AppData\Local\Temp\ipykernel_5696\150256929.py:1: UserWarning: Parsing '13-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\Sravya.nekkanti\AppData\Local\Temp\ipykernel_5696\150256929.py:1: UserWarning: Parsing '14-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\Sravya.nekkanti\AppData\Local\Temp\ipykernel_5696\150256929.py:1: UserWarning: Parsing '15-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   df['Date'] = pd.to_datetime(df['Date'])
# C:\Users\Sravya.nekkanti\AppData\Local\Temp\ipykernel_5696\150256929.py:1: UserWarning: Parsing '16-01-2018' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %%
plt.plot(df['Date'], df['temp_max'], 'ro')
plt.show()

# %%
data = df[['Date', 'temp_max']]
data
# Out:
#               Date  temp_max
# 202950  2018-01-01      30.7
# 202951  2018-02-01      29.8
# 202952  2018-03-01      31.0
# 202953  2018-04-01      29.9
# 202954  2018-05-01      28.8
# ...            ...       ...
# 1173100 2022-09-26      32.7
# 1173101 2022-09-27      32.2
# 1173102 2022-09-28      31.5
# 1173103 2022-09-29      32.5
# 1173104 2022-09-30      30.8
#
# [1870 rows x 2 columns]

# %%
data.dropna(inplace=True)
data.columns = ['ds', 'y'] 
data.tail()
# Out:
# C:\Users\Sravya.nekkanti\AppData\Local\Temp\ipykernel_5696\3700825206.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.dropna(inplace=True)
#                 ds     y
# 1173100 2022-09-26  32.7
# 1173101 2022-09-27  32.2
# 1173102 2022-09-28  31.5
# 1173103 2022-09-29  32.5
# 1173104 2022-09-30  30.8

# %%
data = data.drop_duplicates()

# %%
data.to_csv('Warangal.csv')
